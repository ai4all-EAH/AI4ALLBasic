# %% [markdown]
# # Dummy Notebook

# %% [markdown]
# Just to have something in the index

# %%
import numpy as np

data=np.genfromtxt("data/bsp.csv",delimiter=',',skip_header=1)

# %%
print(data)
# Out:
# [[  1.   1.]
#  [  2.   4.]
#  [  3.   9.]
#  [  4.  16.]
#  [  5.  25.]
#  [  6.  36.]
#  [  7.  49.]
#  [  8.  64.]
#  [  9.  81.]
#  [ 10. 100.]]

# %% [markdown]
# ... und tschüß ... :-)
