# %%
from questions import *

Q1 = create_int_input_widget("Wie viele Zeilen enthält der Datensatz?", [], 3205)
Q2 = create_float_input_widget("Was ist der min Wert der IMDB-Bewertung?", [], 1.4)
Q3 = create_int_input_widget("Was ist der min Wert der Rotten-Tomatoes-Bewertung?", [], 1)
Q4 = create_float_input_widget("Was ist der max Wert der IMDB-Bewertung?", [], 9.2)
Q5 = create_int_input_widget("Was ist der max Wert der Rotten-Tomatoes-Bewertung?", [], 100)
Q6 = create_multipleChoice_widget_new("Welche Spalte enthält die meisten fehlenden Werte", [], 
    ['Rotten-Tomatoes-Bewertung',
     'Laufzeit_min',
     'Hauptgenre',
     'IMDB-Bewertung'], 
    'Laufzeit_min', 0)

display(Q1)
display(Code('\n'))
display(Q2)
display(Code('\n'))
display(Q3)
display(Code('\n'))
display(Q4)
display(Code('\n'))
display(Q5)
display(Code('\n'))
display(Q6)
# Out:
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
# \begin{Verbatim}[commandchars=\\\{\}]
#
# \end{Verbatim}
# ...
