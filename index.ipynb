# %% [markdown]
# # AI4ALL Basic Jupyter Hub

# %% [markdown]
# - [AI4ALL Basic Notebooks WiSe 2023/24](AI4ALLNotebooks/_index.ipynb)

# %% [markdown]
# - [JuPy Course](JuPyTutorialV2.1/00_Einleitung.ipynb)

# %% [markdown]
# here comes the copyright etc
